# %%
import os
import cv2
import numpy as np
import scipy.io

# %%
def extract_instances(img_file, mat_file, outline_colour, output_dir):
    os.makedirs(output_dir, exist_ok=True)


    # Load the matrix file
    mat_data = scipy.io.loadmat(mat_file)

# %%
img_file = "../Image_10646.jpg"
mat_file = "../Image_10646.mat"

mat_data = scipy.io.loadmat(mat_file)

print(mat_data.keys())
print(mat_data["inst_map"][0])
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'inst_map', 'type', 'id', 'type_map'])
# [0. 0. 0. ... 3. 3. 3.]
