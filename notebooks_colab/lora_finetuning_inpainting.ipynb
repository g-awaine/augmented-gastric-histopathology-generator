# %%
# %pip install diffusers accelerate

# %%
# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cu130
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu130
# ...

# %%
# !git clone https://github.com/huggingface/diffusers
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 130016, done.
# remote: Counting objects: 100% (696/696), done.
# remote: Compressing objects: 100% (479/479), done.
# remote: Total 130016 (delta 515), reused 217 (delta 217), pack-reused 129320 (from 4)
# Receiving objects: 100% (130016/130016), 104.65 MiB | 23.01 MiB/s, done.
# Resolving deltas: 100% (96955/96955), done.

# %%
# %cd diffusers/examples/research_projects/dreambooth_inpaint
# Out:
# /content/diffusers/examples/research_projects/flux_lora_quantization

# %%
# %pip install -r requirements_flux.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.0 MB/s eta 0:00:00
# ...

# %%
# %pip install -U git+https://github.com/huggingface/diffusers
# Out:
# ...
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-qv1m_g5i
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-qv1m_g5i
#   Resolved https://github.com/huggingface/diffusers to commit 53e5b00d997c769225b289ef6ab5c2f4640463bf
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.40.0.dev0-py3-none-any.whl size=5685449 sha256=87314fa91080edf6348878f55cc67417b089e7e9fdeff0324cd11e51a5fb637d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oks7h_q2/wheels/90/d4/44/a58bc00fb405fefb633b0d9d2307f6e3aec6cc1775d82555d3
# Successfully built diffusers
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.39.0
#     Uninstalling diffusers-0.39.0:
#       Successfully uninstalled diffusers-0.39.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Path where you want the local shortcut/symlink to be
symlink_path = '/content/healthy2im'

# Target path inside your mounted Google Drive
target_path = '/content/drive/MyDrive/syntheticdata/healthy2im'

# Create the symlink (if it doesn't already exist)
if not os.path.exists(symlink_path):
    os.symlink(target_path, symlink_path)
    print("Symbolic link created successfully!")
# Out:
# Symbolic link created successfully!

# %%
# %env MODEL_NAME=black-forest-labs/FLUX.1-Fill-dev
# %env INSTANCE_DIR=/content/healthy2im/trainB
# %env OUTPUT_DIR=/content

# !accelerate launch --config_file=accelerate.yaml \
  train_dreambooth_lora_flux_miniature.py \
  --pretrained_model_name_or_path="black-forest-labs/FLUX.1-dev" \
  --data_df_path="embeddings.parquet" \
  --output_dir="yarn_art_lora_flux_nf4" \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --weighting_scheme="none" \
  --resolution=1024 \
  --train_batch_size=1 \
  --repeats=1 \
  --learning_rate=1e-4 \
  --guidance_scale=1 \
  --report_to="wandb" \
  --gradient_accumulation_steps=4 \
  --gradient_checkpointing \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --cache_latents \
  --rank=4 \
  --max_train_steps=700 \
  --seed="0"
# Out:
# env: MODEL_NAME=black-forest-labs/FLUX.1-Fill-dev
# env: INSTANCE_DIR=/content/healthy2im/trainB
# env: OUTPUT_DIR=/content
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# /usr/bin/python3: can't open file '/content/diffusers/examples/research_projects/dreambooth_inpaint/train_dreambooth_lora_flux.py': [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/accelerate", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/accelerate/commands/accelerate_cli.py", line 50, in main
#     args.func(args)
# ...

# %%
# %env MODEL_NAME=stable-diffusion-v1-5/stable-diffusion-inpainting
# %env INSTANCE_DIR=/content/healthy2im/trainB
# %env OUTPUT_DIR=/content

accelerate launch --config_file=accelerate.yaml \
  train_dreambooth_lora_flux_miniature.py \
  --pretrained_model_name_or_path="black-forest-labs/FLUX.1-dev" \
  --data_df_path="embeddings.parquet" \
  --output_dir="yarn_art_lora_flux_nf4" \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --weighting_scheme="none" \
  --resolution=1024 \
  --train_batch_size=1 \
  --repeats=1 \
  --learning_rate=1e-4 \
  --guidance_scale=1 \
  --report_to="wandb" \
  --gradient_accumulation_steps=4 \
  --gradient_checkpointing \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --cache_latents \
  --rank=4 \
  --max_train_steps=700 \
  --seed="0"
# Out:
# env: MODEL_NAME=stable-diffusion-v1-5/stable-diffusion-inpainting
# env: INSTANCE_DIR=/content/healthy2im/trainB
# env: OUTPUT_DIR=/content
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Loading weights: 100% 196/196 [00:00<00:00, 34335.03it/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# ...

# %%
from huggingface_hub import login
login("")

# %%
# !git clone https://github.com/nikgli/train-lora-sdxl-inpaint.git
# %cd train-lora-sdxl-inpaint/diffusers && pip install -e .
# %pip install -r train-lora-sdxl-inpaint/diffusers/examples/research_projects/requirements.txt
# %pip install -U "huggingface_hub[cli]"

# %%
# !huggingface-cli download diffusers/stable-diffusion-xl-1.0-inpainting-0.1 --local-dir ./models/sdxl-inpainting-1.0 --local-dir-use-symlinks False

# %%
# !accelerate launch examples/research_projects/dreambooth_inpaint/train_dreambooth_inpaint_lora_sdxl.py \
    --pretrained_model_name_or_path="./models/sdxl-inpainting-1.0" \
    --instance_data_dir="./dataset/your-subject-images-directory" \
    --output_dir="./lora-weights/sks-your-subject-sdxl-from-inpainting" \
    --instance_prompt="a photo of a sks dog" \
    --mixed_precision="fp16" \
    --resolution=1024 \
    --train_batch_size=1 \
    --gradient_accumulation_steps=4 \
    --learning_rate=1e-4 \
    --lr_scheduler="constant" \
    --lr_warmup_steps=0 \
    --max_train_steps=500 \
    --seed="42" \
